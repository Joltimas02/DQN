# %%
import gym
from gym import spaces
import numpy as np

class WarehouseOrientationEnv(gym.Env):
    """
    Magazyn NxN z orientacją robota:
      - Stan: [r_x, r_y, t_x, t_y, orientation_index]
      - Akcje: 0=obrót w lewo (alpha), 1=obrót w prawo (alpha), 2=ruch do przodu
    """
    def __init__(self, n=5, alpha=90, max_steps=100):
        super(WarehouseOrientationEnv, self).__init__()

        self.n = n
        self.alpha = alpha
        self.max_steps = max_steps

        # Ilu "kroków" orientacji mamy (alpha musi dzielić 360)
        assert 360 % alpha == 0, "Kąt alpha musi dzielić 360 (np. 90, 45, 60 itp.)"
        self.num_orientations = 360 // alpha

        # Przestrzeń akcji: 3 akcje
        #  0: obrót w lewo o alpha
        #  1: obrót w prawo o alpha
        #  2: ruch do przodu
        self.action_space = spaces.Discrete(3)

        # Przestrzeń stanów = Box, 5 wymiarów:
        #   r_x, r_y, t_x, t_y, orientation_index
        # r_x, r_y, t_x, t_y w [0, n-1]
        # orientation_index w [0, num_orientations - 1]
        low = np.array([0, 0, 0, 0, 0], dtype=np.float32)
        high = np.array([n-1, n-1, n-1, n-1, self.num_orientations - 1], dtype=np.float32)
        self.observation_space = spaces.Box(low, high, dtype=np.float32)

        # Pola do przechowywania stanu
        self.robot_x = 0
        self.robot_y = 0
        self.target_x = 0
        self.target_y = 0
        self.orientation = 0  # indeks 0..num_orientations-1
        self.current_step = 0
        self.reward=0
        self.terminated=False
    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = 0
        self.terminated=False
        # Losujemy pozycję robota
        self.robot_x = np.random.randint(self.n)
        self.robot_y = np.random.randint(self.n)
        self.reward=0
        # Losujemy pozycję celu (inną niż robota)
        while True:
            self.target_x = np.random.randint(self.n)
            self.target_y = np.random.randint(self.n)
            if (self.target_x != self.robot_x) or (self.target_y != self.robot_y):
                break

        # Losujemy orientację (0..num_orientations-1)
        self.orientation = np.random.randint(self.num_orientations)

        return self._get_obs()

    def step(self, action):
        self.reward=0
        old_distance = np.linalg.norm([
            self.robot_x - self.target_x,
            self.robot_y - self.target_y
        ])

        # Wykonujemy akcję
        if action == 0:
            # Obrót w lewo
            reward=-0.
            self.orientation = (self.orientation - 1) % self.num_orientations
        elif action == 1:
            # Obrót w prawo
            reward=-0.
            self.orientation = (self.orientation + 1) % self.num_orientations
        elif action == 2:
            # Ruch do przodu
            reward=0
            self._move_forward()
        else:
            raise ValueError(f"Nieznana akcja: {action}")

        # Domyślna niewielka kara za ruch
        reward += -0.0001
        terminated = self.terminated

        new_distance = np.linalg.norm([
        self.robot_x - self.target_x,
        self.robot_y - self.target_y
        ])

        # Nagroda na podstawie odwrotności odległości
        if new_distance-old_distance < 0:  # Unikamy dzielenia przez zero
          reward += 0.1
        elif old_distance-new_distance > 0:
            reward-=0.1
        else:
    # Maksymalna nagroda, jeśli osiągnięto cel (odległość = 0)
          reward += 0


        # Sprawdzamy, czy dotarliśmy do celu
        if (self.robot_x == self.target_x) and (self.robot_y == self.target_y):
            reward = 1.0

            terminated = True

        # Sprawdzamy, czy przekroczyliśmy limit kroków
        obs = self._get_obs()
        self.current_step += 1
        truncated = (self.current_step >= self.max_steps)


        return obs, reward+self.reward, terminated, truncated

    def render(self, mode='human'):
        """
        Prosta wizualizacja tekstowa w konsoli.
        'R' = robot
        'T' = cel
        '.' = puste
        """
        grid = [["." for _ in range(self.n)] for _ in range(self.n)]

        # robot
        grid[self.robot_y][self.robot_x] = "R"
        # cel
        grid[self.target_y][self.target_x] = "T"

        print("="*(2*self.n))
        for row in grid:
            print(" ".join(row))
        print("="*(2*self.n))
        print(f"Orientacja (indeks): {self.orientation} (kąt = {self.orientation * self.alpha} stopni)")

    def _get_obs(self):
        """
        Zwracamy krotkę (lub tablicę) [robot_x, robot_y, target_x, target_y, orientation].
        """
        return np.array([self.robot_x,
                         self.robot_y,
                         self.target_x,
                         self.target_y,
                         self.orientation])

    def _move_forward(self):
        """
        Ruch o 1 'kratkę' w kierunku orientation.
        orientation * alpha -> kąt w stopniach.
        """
        angle_deg = self.orientation * self.alpha
        # Konwersja na radians
        angle_rad = np.deg2rad(angle_deg)

        # Wektor ruchu
        dx = int(round(np.cos(angle_rad)))
        dy = int(round(np.sin(angle_rad)))

        # Sprawdzamy, czy wyjście w [0..n-1]
        new_x = self.robot_x + dx
        new_y = self.robot_y + dy

        if 0 <= new_x < self.n and 0 <= new_y < self.n:
            self.robot_x = new_x
            self.robot_y = new_y
        else:
          self.reward=-0.5
          self.terminated=True

# %%
import numpy as np

import tensorflow as tf
from tensorflow.keras import models, layers, optimizers
from collections import deque
import random

GAMMA = 0.1
EPSILON_START = 1.0
EPSILON_MIN = 0.0
EPSILON_DECAY = 0.5
BATCH_SIZE =4000
LEARNING_RATE = 0.000001
MEMORY_SIZE = 20000000
EPISODES = 200000

# Przykładowe środowisko, które zwraca obs shape=(5,)
env = WarehouseOrientationEnv(n=64, max_steps=200)

###############################################################################
# 1) Funkcja transformująca stan 5D -> 6D:
#    Załóżmy, że obs[4] = {0,1,2,3} => kąty 0°, 90°, 180°, 270°
###############################################################################
def transform_state(obs):
    """
    obs ma postać [x0, x1, x2, x3, orientation].
    Zwracamy [x0, x1, x2, x3, sin(kąta), cos(kąta)],
    czyli wektor o rozmiarze 6.
    """
    obs = np.array(obs, dtype=float)  # Upewnij się, że float

    orientation = obs[4]   # np. 0,1,2,3
    angle_deg = orientation * 90.0
    angle_rad = np.deg2rad(angle_deg)
    sin_v = np.sin(angle_rad)
    cos_v = np.cos(angle_rad)

    # Sklejamy: 4 pierwsze elementy + sin + cos
    new_obs = np.concatenate([obs[:4], [sin_v, cos_v]])
    return new_obs

###############################################################################
# 2) Zmieniamy state_size na 6
###############################################################################
state_size = 6
action_size = env.action_space.n  # np. 3

def build_q_network(state_size, action_size):
    model = models.Sequential()
    model.add(layers.Dense(128, input_shape=(state_size,), activation='relu')) 
    model.add(layers.Dense(action_size, activation='linear'))
    model.compile(optimizer=optimizers.Adam(learning_rate=LEARNING_RATE), loss='mse')
    return model

def build_target_network(model):
    target = models.clone_model(model)
    target.set_weights(model.get_weights())
    return target

q_network = build_q_network(state_size, action_size)
target_network = build_target_network(q_network)

#memory = deque(maxlen=MEMORY_SIZE)
epsilon = EPSILON_START
all_rewards = []
loss_value = 0.0  # Zmienna do przechowywania bieżącej wartości loss

###############################################################################
# 3) Główna pętla treningowa
###############################################################################
for episode in range(EPISODES):
    # Resetujemy środowisko -> obs ma wymiar (5,)
    obs = env.reset()
    # Zamieniamy go na wymiar (6,)
    obs = transform_state(obs)

    done = False
    total_reward = 0
    terminated =False
    truncated=False
    while not (terminated or truncated) :
        # Epsilon-greedy
        if np.random.rand() < epsilon or len(memory)<190000:
            action = np.random.randint(action_size)
        else:
            q_values = q_network.predict(obs[np.newaxis, :], verbose=0)
            action = np.argmax(q_values[0])

        # Step w środowisku => dostajemy next_obs (5D)
        next_obs, reward, terminated, truncated = env.step(action)
        # Zamieniamy na 6D
        next_obs = transform_state(next_obs)

        done = terminated
        total_reward += reward

        # Zapisujemy w pamięci
        memory.append((obs, action, reward, next_obs, done))

        # Przechodzimy do nowej obserwacji
        obs = next_obs

    # Uczenie sieci, jeśli mamy wystarczającą ilość danych w pamięci
    if  len(memory)>=190000:
        minibatch = random.sample(memory, BATCH_SIZE)
        #print(minibatch)
        states_mb      = np.array([m[0] for m in minibatch])  # shape=(BATCH_SIZE, 6)
        actions_mb     = np.array([m[1] for m in minibatch])
        rewards_mb     = np.array([m[2] for m in minibatch])
        next_states_mb = np.array([m[3] for m in minibatch])
        dones_mb       = np.array([m[4] for m in minibatch])

        q_next        = q_network.predict(next_states_mb, verbose=0)
        q_next_target = target_network.predict(next_states_mb, verbose=0)
        q_targets     = q_network.predict(states_mb, verbose=0)

        for i in range(BATCH_SIZE):
            if dones_mb[i]:
                q_targets[i, actions_mb[i]] = rewards_mb[i]
            else:
                a_max = np.argmax(q_next[i])
                q_targets[i, actions_mb[i]] = rewards_mb[i] + GAMMA * q_next_target[i, a_max]

        # Trenujemy Q-network i przechwytujemy wartość loss
        # Zapisujemy loss z pojedynczej epoki treningu
        history = q_network.fit(states_mb, q_targets, epochs=1, verbose=0)
        loss_value = history.history['loss'][0]



                # Zapisanie loss do TensorBoard
        #global_step += 1  # zwiększamy licznik kroków
        #with train_summary_writer.as_default():
         # tf.summary.scalar('loss', data=loss_value, step=global_step)
        q_weights = q_network.get_weights()
        target_weights = target_network.get_weights()
        #for i in range(len(target_weights)):
        #target_weights[i] = 0.05 * q_weights[i] + (1.0 - 0.01) * target_weights[i]
          #target_network.set_weights(target_weights)
    # Zmniejszamy epsilon
    if epsilon > EPSILON_MIN:
        epsilon *= EPSILON_DECAY

    all_rewards.append(total_reward)

    # Okresowe kopiowanie wag do sieci target
    if episode % 5 == 0:
       target_network.set_weights(q_network.get_weights())

    # Monitoring co 5 epizodów (przykładowo)
    if (episode + 1) % 1 == 0:
        avg_reward = np.mean(all_rewards[-10:])
        print(f"Epizod: {episode+1}/{EPISODES}, "
              f"średni reward z ostatnich 10 epizodów: {avg_reward:.3f}, "
              f"epsilon: {epsilon:.3f}, "
              f"loss: {loss_value:.5f}")

print("Trening zakończony!")
# Out:
# Epizod: 1/200000, średni reward z ostatnich 10 epizodów: 2.880, epsilon: 0.500, loss: 13.31209
# Epizod: 2/200000, średni reward z ostatnich 10 epizodów: 1.789, epsilon: 0.250, loss: 13.22745
# Epizod: 3/200000, średni reward z ostatnich 10 epizodów: 1.225, epsilon: 0.125, loss: 12.74158
# Epizod: 4/200000, średni reward z ostatnich 10 epizodów: 2.091, epsilon: 0.062, loss: 12.03764
# Epizod: 5/200000, średni reward z ostatnich 10 epizodów: 1.572, epsilon: 0.031, loss: 11.55376
# Epizod: 6/200000, średni reward z ostatnich 10 epizodów: 1.557, epsilon: 0.016, loss: 11.53930
# Epizod: 7/200000, średni reward z ostatnich 10 epizodów: 1.263, epsilon: 0.008, loss: 11.18775
# Epizod: 8/200000, średni reward z ostatnich 10 epizodów: 1.155, epsilon: 0.004, loss: 11.01095
# Epizod: 9/200000, średni reward z ostatnich 10 epizodów: 0.982, epsilon: 0.002, loss: 10.15012
# Epizod: 10/200000, średni reward z ostatnich 10 epizodów: 1.133, epsilon: 0.001, loss: 9.93746
# Epizod: 11/200000, średni reward z ostatnich 10 epizodów: 0.795, epsilon: 0.000, loss: 9.52328
# Epizod: 12/200000, średni reward z ostatnich 10 epizodów: 0.675, epsilon: 0.000, loss: 9.60996
# Epizod: 13/200000, średni reward z ostatnich 10 epizodów: 0.943, epsilon: 0.000, loss: 9.17969
# Epizod: 14/200000, średni reward z ostatnich 10 epizodów: 0.954, epsilon: 0.000, loss: 8.77299
# Epizod: 15/200000, średni reward z ostatnich 10 epizodów: 0.953, epsilon: 0.000, loss: 8.43228
# Epizod: 16/200000, średni reward z ostatnich 10 epizodów: 0.755, epsilon: 0.000, loss: 8.27948
# Epizod: 17/200000, średni reward z ostatnich 10 epizodów: 0.755, epsilon: 0.000, loss: 7.99734
# Epizod: 18/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 7.79087
# Epizod: 19/200000, średni reward z ostatnich 10 epizodów: 0.885, epsilon: 0.000, loss: 7.31809
# Epizod: 20/200000, średni reward z ostatnich 10 epizodów: 0.795, epsilon: 0.000, loss: 7.36691
# Epizod: 21/200000, średni reward z ostatnich 10 epizodów: 0.795, epsilon: 0.000, loss: 6.98343
# Epizod: 22/200000, średni reward z ostatnich 10 epizodów: 0.835, epsilon: 0.000, loss: 6.90601
# Epizod: 23/200000, średni reward z ostatnich 10 epizodów: 0.506, epsilon: 0.000, loss: 6.19197
# Epizod: 24/200000, średni reward z ostatnich 10 epizodów: 0.017, epsilon: 0.000, loss: 6.32829
# Epizod: 25/200000, średni reward z ostatnich 10 epizodów: 0.065, epsilon: 0.000, loss: 6.23327
# Epizod: 26/200000, średni reward z ostatnich 10 epizodów: 0.065, epsilon: 0.000, loss: 6.13692
# Epizod: 27/200000, średni reward z ostatnich 10 epizodów: 0.173, epsilon: 0.000, loss: 5.48276
# Epizod: 28/200000, średni reward z ostatnich 10 epizodów: 0.123, epsilon: 0.000, loss: 5.50188
# Epizod: 29/200000, średni reward z ostatnich 10 epizodów: 0.113, epsilon: 0.000, loss: 5.34172
# Epizod: 30/200000, średni reward z ostatnich 10 epizodów: 0.003, epsilon: 0.000, loss: 4.96774
# Epizod: 31/200000, średni reward z ostatnich 10 epizodów: 0.512, epsilon: 0.000, loss: 4.82469
# Epizod: 32/200000, średni reward z ostatnich 10 epizodów: 0.473, epsilon: 0.000, loss: 4.80465
# Epizod: 33/200000, średni reward z ostatnich 10 epizodów: 0.503, epsilon: 0.000, loss: 4.56979
# Epizod: 34/200000, średni reward z ostatnich 10 epizodów: 0.752, epsilon: 0.000, loss: 4.49380
# Epizod: 35/200000, średni reward z ostatnich 10 epizodów: 0.854, epsilon: 0.000, loss: 4.25848
# Epizod: 36/200000, średni reward z ostatnich 10 epizodów: 1.222, epsilon: 0.000, loss: 4.07824
# Epizod: 37/200000, średni reward z ostatnich 10 epizodów: 1.114, epsilon: 0.000, loss: 4.00171
# Epizod: 38/200000, średni reward z ostatnich 10 epizodów: 1.114, epsilon: 0.000, loss: 3.83726
# Epizod: 39/200000, średni reward z ostatnich 10 epizodów: 0.944, epsilon: 0.000, loss: 3.66673
# Epizod: 40/200000, średni reward z ostatnich 10 epizodów: 0.893, epsilon: 0.000, loss: 3.69788
# Epizod: 41/200000, średni reward z ostatnich 10 epizodów: 0.384, epsilon: 0.000, loss: 3.39766
# Epizod: 42/200000, średni reward z ostatnich 10 epizodów: 0.733, epsilon: 0.000, loss: 3.38336
# Epizod: 43/200000, średni reward z ostatnich 10 epizodów: 0.813, epsilon: 0.000, loss: 3.09941
# Epizod: 44/200000, średni reward z ostatnich 10 epizodów: 0.663, epsilon: 0.000, loss: 3.20113
# Epizod: 45/200000, średni reward z ostatnich 10 epizodów: 0.514, epsilon: 0.000, loss: 3.03227
# Epizod: 46/200000, średni reward z ostatnich 10 epizodów: 0.194, epsilon: 0.000, loss: 2.91265
# Epizod: 47/200000, średni reward z ostatnich 10 epizodów: 0.242, epsilon: 0.000, loss: 2.76819
# Epizod: 48/200000, średni reward z ostatnich 10 epizodów: 0.472, epsilon: 0.000, loss: 2.68412
# Epizod: 49/200000, średni reward z ostatnich 10 epizodów: 0.472, epsilon: 0.000, loss: 2.64146
# Epizod: 50/200000, średni reward z ostatnich 10 epizodów: 0.424, epsilon: 0.000, loss: 2.58903
# Epizod: 51/200000, średni reward z ostatnich 10 epizodów: 0.643, epsilon: 0.000, loss: 2.45676
# Epizod: 52/200000, średni reward z ostatnich 10 epizodów: 0.323, epsilon: 0.000, loss: 2.33573
# Epizod: 53/200000, średni reward z ostatnich 10 epizodów: 0.262, epsilon: 0.000, loss: 2.37727
# Epizod: 54/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 2.16672
# Epizod: 55/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 2.06850
# Epizod: 56/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 2.02358
# Epizod: 57/200000, średni reward z ostatnich 10 epizodów: 0.273, epsilon: 0.000, loss: 2.06035
# Epizod: 58/200000, średni reward z ostatnich 10 epizodów: 0.503, epsilon: 0.000, loss: 1.98994
# Epizod: 59/200000, średni reward z ostatnich 10 epizodów: 0.553, epsilon: 0.000, loss: 1.83512
# Epizod: 60/200000, średni reward z ostatnich 10 epizodów: 0.601, epsilon: 0.000, loss: 1.79492
# Epizod: 61/200000, średni reward z ostatnich 10 epizodów: 0.430, epsilon: 0.000, loss: 1.74596
# Epizod: 62/200000, średni reward z ostatnich 10 epizodów: 0.448, epsilon: 0.000, loss: 1.68066
# Epizod: 63/200000, średni reward z ostatnich 10 epizodów: 0.600, epsilon: 0.000, loss: 1.75304
# Epizod: 64/200000, średni reward z ostatnich 10 epizodów: 0.580, epsilon: 0.000, loss: 1.68011
# Epizod: 65/200000, średni reward z ostatnich 10 epizodów: 0.628, epsilon: 0.000, loss: 1.66239
# Epizod: 66/200000, średni reward z ostatnich 10 epizodów: 0.628, epsilon: 0.000, loss: 1.52082
# Epizod: 67/200000, średni reward z ostatnich 10 epizodów: 0.497, epsilon: 0.000, loss: 1.57421
# Epizod: 68/200000, średni reward z ostatnich 10 epizodów: 0.157, epsilon: 0.000, loss: 1.49482
# Epizod: 69/200000, średni reward z ostatnich 10 epizodów: 0.155, epsilon: 0.000, loss: 1.43917
# Epizod: 70/200000, średni reward z ostatnich 10 epizodów: 0.155, epsilon: 0.000, loss: 1.37580
# Epizod: 71/200000, średni reward z ostatnich 10 epizodów: 0.527, epsilon: 0.000, loss: 1.40436
# Epizod: 72/200000, średni reward z ostatnich 10 epizodów: 0.527, epsilon: 0.000, loss: 1.39977
# Epizod: 73/200000, średni reward z ostatnich 10 epizodów: 0.375, epsilon: 0.000, loss: 1.34989
# Epizod: 74/200000, średni reward z ostatnich 10 epizodów: 0.374, epsilon: 0.000, loss: 1.35385
# Epizod: 75/200000, średni reward z ostatnich 10 epizodów: 0.374, epsilon: 0.000, loss: 1.22462
# Epizod: 76/200000, średni reward z ostatnich 10 epizodów: 0.374, epsilon: 0.000, loss: 1.25445
# Epizod: 77/200000, średni reward z ostatnich 10 epizodów: 0.366, epsilon: 0.000, loss: 1.29607
# Epizod: 78/200000, średni reward z ostatnich 10 epizodów: 0.624, epsilon: 0.000, loss: 1.19013
# Epizod: 79/200000, średni reward z ostatnich 10 epizodów: 0.624, epsilon: 0.000, loss: 1.18436
# Epizod: 80/200000, średni reward z ostatnich 10 epizodów: 0.624, epsilon: 0.000, loss: 1.14856
# Epizod: 81/200000, średni reward z ostatnich 10 epizodów: 0.253, epsilon: 0.000, loss: 1.13728
# Epizod: 82/200000, średni reward z ostatnich 10 epizodów: 0.253, epsilon: 0.000, loss: 1.13494
# Epizod: 83/200000, średni reward z ostatnich 10 epizodów: 0.734, epsilon: 0.000, loss: 1.11452
# Epizod: 84/200000, średni reward z ostatnich 10 epizodów: 0.844, epsilon: 0.000, loss: 1.11048
# Epizod: 85/200000, średni reward z ostatnich 10 epizodów: 0.984, epsilon: 0.000, loss: 1.09458
# Epizod: 86/200000, średni reward z ostatnich 10 epizodów: 1.224, epsilon: 0.000, loss: 1.05372
# Epizod: 87/200000, średni reward z ostatnich 10 epizodów: 1.233, epsilon: 0.000, loss: 1.04016
# Epizod: 88/200000, średni reward z ostatnich 10 epizodów: 0.903, epsilon: 0.000, loss: 1.01193
# Epizod: 89/200000, średni reward z ostatnich 10 epizodów: 0.903, epsilon: 0.000, loss: 0.99903
# Epizod: 90/200000, średni reward z ostatnich 10 epizodów: 0.903, epsilon: 0.000, loss: 0.97545
# Epizod: 91/200000, średni reward z ostatnich 10 epizodów: 0.903, epsilon: 0.000, loss: 0.98737
# Epizod: 92/200000, średni reward z ostatnich 10 epizodów: 1.333, epsilon: 0.000, loss: 0.97799
# Epizod: 93/200000, średni reward z ostatnich 10 epizodów: 0.853, epsilon: 0.000, loss: 0.90280
# Epizod: 94/200000, średni reward z ostatnich 10 epizodów: 0.863, epsilon: 0.000, loss: 0.90276
# Epizod: 95/200000, średni reward z ostatnich 10 epizodów: 1.063, epsilon: 0.000, loss: 0.89911
# Epizod: 96/200000, średni reward z ostatnich 10 epizodów: 1.104, epsilon: 0.000, loss: 0.88812
# Epizod: 97/200000, średni reward z ostatnich 10 epizodów: 1.104, epsilon: 0.000, loss: 0.84759
# Epizod: 98/200000, średni reward z ostatnich 10 epizodów: 1.104, epsilon: 0.000, loss: 0.82706
# Epizod: 99/200000, średni reward z ostatnich 10 epizodów: 1.055, epsilon: 0.000, loss: 0.84714
# Epizod: 100/200000, średni reward z ostatnich 10 epizodów: 1.055, epsilon: 0.000, loss: 0.83013
# Epizod: 101/200000, średni reward z ostatnich 10 epizodów: 1.055, epsilon: 0.000, loss: 0.82202
# Epizod: 102/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 0.78106
# Epizod: 103/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 0.78170
# Epizod: 104/200000, średni reward z ostatnich 10 epizodów: 0.643, epsilon: 0.000, loss: 0.76930
# Epizod: 105/200000, średni reward z ostatnich 10 epizodów: 0.303, epsilon: 0.000, loss: 0.71230
# Epizod: 106/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.75175
# Epizod: 107/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.72476
# Epizod: 108/200000, średni reward z ostatnich 10 epizodów: 0.025, epsilon: 0.000, loss: 0.75318
# Epizod: 109/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.72606
# Epizod: 110/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.71413
# Epizod: 111/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.63775
# Epizod: 112/200000, średni reward z ostatnich 10 epizodów: -0.016, epsilon: 0.000, loss: 0.68984
# Epizod: 113/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.65534
# Epizod: 114/200000, średni reward z ostatnich 10 epizodów: 0.025, epsilon: 0.000, loss: 0.63940
# Epizod: 115/200000, średni reward z ostatnich 10 epizodów: 0.025, epsilon: 0.000, loss: 0.61525
# Epizod: 116/200000, średni reward z ostatnich 10 epizodów: -0.026, epsilon: 0.000, loss: 0.59859
# Epizod: 117/200000, średni reward z ostatnich 10 epizodów: -0.026, epsilon: 0.000, loss: 0.57952
# Epizod: 118/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.57957
# Epizod: 119/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.59604
# Epizod: 120/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.56517
# Epizod: 121/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.55489
# Epizod: 122/200000, średni reward z ostatnich 10 epizodów: 0.165, epsilon: 0.000, loss: 0.51829
# Epizod: 123/200000, średni reward z ostatnich 10 epizodów: 0.075, epsilon: 0.000, loss: 0.53133
# Epizod: 124/200000, średni reward z ostatnich 10 epizodów: 0.123, epsilon: 0.000, loss: 0.50603
# Epizod: 125/200000, średni reward z ostatnich 10 epizodów: 0.123, epsilon: 0.000, loss: 0.52951
# Epizod: 126/200000, średni reward z ostatnich 10 epizodów: 0.123, epsilon: 0.000, loss: 0.47560
# Epizod: 127/200000, średni reward z ostatnich 10 epizodów: 0.075, epsilon: 0.000, loss: 0.49956
# Epizod: 128/200000, średni reward z ostatnich 10 epizodów: 0.075, epsilon: 0.000, loss: 0.51169
# Epizod: 129/200000, średni reward z ostatnich 10 epizodów: 0.067, epsilon: 0.000, loss: 0.49699
# Epizod: 130/200000, średni reward z ostatnich 10 epizodów: 0.105, epsilon: 0.000, loss: 0.46587
# Epizod: 131/200000, średni reward z ostatnich 10 epizodów: 0.107, epsilon: 0.000, loss: 0.45387
# Epizod: 132/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.47343
# Epizod: 133/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.45393
# Epizod: 134/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.42654
# Epizod: 135/200000, średni reward z ostatnich 10 epizodów: -0.065, epsilon: 0.000, loss: 0.42796
# Epizod: 136/200000, średni reward z ostatnich 10 epizodów: -0.024, epsilon: 0.000, loss: 0.42185
# Epizod: 137/200000, średni reward z ostatnich 10 epizodów: -0.024, epsilon: 0.000, loss: 0.43935
# Epizod: 138/200000, średni reward z ostatnich 10 epizodów: -0.024, epsilon: 0.000, loss: 0.40638
# Epizod: 139/200000, średni reward z ostatnich 10 epizodów: -0.015, epsilon: 0.000, loss: 0.41037
# Epizod: 140/200000, średni reward z ostatnich 10 epizodów: -0.015, epsilon: 0.000, loss: 0.39461
# Epizod: 141/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.39993
# Epizod: 142/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.38339
# Epizod: 143/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.37124
# Epizod: 144/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.35454
# Epizod: 145/200000, średni reward z ostatnich 10 epizodów: -0.027, epsilon: 0.000, loss: 0.36819
# Epizod: 146/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.34908
# Epizod: 147/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.34977
# Epizod: 148/200000, średni reward z ostatnich 10 epizodów: 0.163, epsilon: 0.000, loss: 0.31687
# Epizod: 149/200000, średni reward z ostatnich 10 epizodów: 0.163, epsilon: 0.000, loss: 0.34146
# Epizod: 150/200000, średni reward z ostatnich 10 epizodów: 0.163, epsilon: 0.000, loss: 0.32456
# Epizod: 151/200000, średni reward z ostatnich 10 epizodów: 0.163, epsilon: 0.000, loss: 0.33326
# Epizod: 152/200000, średni reward z ostatnich 10 epizodów: 0.163, epsilon: 0.000, loss: 0.31445
# Epizod: 153/200000, średni reward z ostatnich 10 epizodów: 0.205, epsilon: 0.000, loss: 0.30595
# Epizod: 154/200000, średni reward z ostatnich 10 epizodów: 0.205, epsilon: 0.000, loss: 0.31798
# Epizod: 155/200000, średni reward z ostatnich 10 epizodów: 0.205, epsilon: 0.000, loss: 0.32567
# Epizod: 156/200000, średni reward z ostatnich 10 epizodów: 0.157, epsilon: 0.000, loss: 0.30281
# Epizod: 157/200000, średni reward z ostatnich 10 epizodów: 0.205, epsilon: 0.000, loss: 0.30085
# Epizod: 158/200000, średni reward z ostatnich 10 epizodów: -0.026, epsilon: 0.000, loss: 0.29688
# Epizod: 159/200000, średni reward z ostatnich 10 epizodów: -0.026, epsilon: 0.000, loss: 0.28162
# Epizod: 160/200000, średni reward z ostatnich 10 epizodów: -0.045, epsilon: 0.000, loss: 0.29560
# Epizod: 161/200000, średni reward z ostatnich 10 epizodów: -0.045, epsilon: 0.000, loss: 0.28109
# Epizod: 162/200000, średni reward z ostatnich 10 epizodów: -0.045, epsilon: 0.000, loss: 0.27094
# Epizod: 163/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.27893
# Epizod: 164/200000, średni reward z ostatnich 10 epizodów: -0.056, epsilon: 0.000, loss: 0.27220
# Epizod: 165/200000, średni reward z ostatnich 10 epizodów: -0.056, epsilon: 0.000, loss: 0.26519
# Epizod: 166/200000, średni reward z ostatnich 10 epizodów: -0.008, epsilon: 0.000, loss: 0.26435
# Epizod: 167/200000, średni reward z ostatnich 10 epizodów: 0.002, epsilon: 0.000, loss: 0.25312
# Epizod: 168/200000, średni reward z ostatnich 10 epizodów: 0.002, epsilon: 0.000, loss: 0.25223
# Epizod: 169/200000, średni reward z ostatnich 10 epizodów: -0.047, epsilon: 0.000, loss: 0.24899
# Epizod: 170/200000, średni reward z ostatnich 10 epizodów: -0.028, epsilon: 0.000, loss: 0.24869
# Epizod: 171/200000, średni reward z ostatnich 10 epizodów: 0.432, epsilon: 0.000, loss: 0.24283
# Epizod: 172/200000, średni reward z ostatnich 10 epizodów: 0.432, epsilon: 0.000, loss: 0.25412
# Epizod: 173/200000, średni reward z ostatnich 10 epizodów: 0.412, epsilon: 0.000, loss: 0.23344
# Epizod: 174/200000, średni reward z ostatnich 10 epizodów: 0.402, epsilon: 0.000, loss: 0.24580
# Epizod: 175/200000, średni reward z ostatnich 10 epizodów: 0.402, epsilon: 0.000, loss: 0.24645
# Epizod: 176/200000, średni reward z ostatnich 10 epizodów: 0.402, epsilon: 0.000, loss: 0.22856
# Epizod: 177/200000, średni reward z ostatnich 10 epizodów: 0.392, epsilon: 0.000, loss: 0.23130
# Epizod: 178/200000, średni reward z ostatnich 10 epizodów: 0.392, epsilon: 0.000, loss: 0.22447
# Epizod: 179/200000, średni reward z ostatnich 10 epizodów: 0.440, epsilon: 0.000, loss: 0.22831
# Epizod: 180/200000, średni reward z ostatnich 10 epizodów: 0.440, epsilon: 0.000, loss: 0.21394
# Epizod: 181/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.21233
# Epizod: 182/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.22160
# Epizod: 183/200000, średni reward z ostatnich 10 epizodów: 0.032, epsilon: 0.000, loss: 0.20673
# Epizod: 184/200000, średni reward z ostatnich 10 epizodów: 0.032, epsilon: 0.000, loss: 0.20600
# Epizod: 185/200000, średni reward z ostatnich 10 epizodów: 0.032, epsilon: 0.000, loss: 0.21893
# Epizod: 186/200000, średni reward z ostatnich 10 epizodów: 0.054, epsilon: 0.000, loss: 0.20263
# Epizod: 187/200000, średni reward z ostatnich 10 epizodów: 0.074, epsilon: 0.000, loss: 0.20160
# Epizod: 188/200000, średni reward z ostatnich 10 epizodów: 0.214, epsilon: 0.000, loss: 0.20796
# Epizod: 189/200000, średni reward z ostatnich 10 epizodów: 0.465, epsilon: 0.000, loss: 0.19689
# Epizod: 190/200000, średni reward z ostatnich 10 epizodów: 0.465, epsilon: 0.000, loss: 0.19481
# Epizod: 191/200000, średni reward z ostatnich 10 epizodów: 0.513, epsilon: 0.000, loss: 0.19008
# Epizod: 192/200000, średni reward z ostatnich 10 epizodów: 0.513, epsilon: 0.000, loss: 0.19891
# Epizod: 193/200000, średni reward z ostatnich 10 epizodów: 0.413, epsilon: 0.000, loss: 0.18253
# Epizod: 194/200000, średni reward z ostatnich 10 epizodów: 0.455, epsilon: 0.000, loss: 0.18868
# Epizod: 195/200000, średni reward z ostatnich 10 epizodów: 0.407, epsilon: 0.000, loss: 0.18496
# Epizod: 196/200000, średni reward z ostatnich 10 epizodów: 0.795, epsilon: 0.000, loss: 0.17257
# Epizod: 197/200000, średni reward z ostatnich 10 epizodów: 0.775, epsilon: 0.000, loss: 0.18022
# Epizod: 198/200000, średni reward z ostatnich 10 epizodów: 0.635, epsilon: 0.000, loss: 0.18379
# Epizod: 199/200000, średni reward z ostatnich 10 epizodów: 0.384, epsilon: 0.000, loss: 0.18274
# Epizod: 200/200000, średni reward z ostatnich 10 epizodów: 0.384, epsilon: 0.000, loss: 0.17515
# Epizod: 201/200000, średni reward z ostatnich 10 epizodów: 0.386, epsilon: 0.000, loss: 0.16827
# Epizod: 202/200000, średni reward z ostatnich 10 epizodów: 0.386, epsilon: 0.000, loss: 0.17294
# Epizod: 203/200000, średni reward z ostatnich 10 epizodów: 0.386, epsilon: 0.000, loss: 0.18382
# Epizod: 204/200000, średni reward z ostatnich 10 epizodów: 0.296, epsilon: 0.000, loss: 0.16354
# Epizod: 205/200000, średni reward z ostatnich 10 epizodów: 0.344, epsilon: 0.000, loss: 0.16751
# Epizod: 206/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.16020
# Epizod: 207/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.17787
# Epizod: 208/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.16527
# Epizod: 209/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.16557
# Epizod: 210/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.16309
# Epizod: 211/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.15888
# Epizod: 212/200000, średni reward z ostatnich 10 epizodów: -0.048, epsilon: 0.000, loss: 0.15928
# Epizod: 213/200000, średni reward z ostatnich 10 epizodów: -0.048, epsilon: 0.000, loss: 0.16161
# Epizod: 214/200000, średni reward z ostatnich 10 epizodów: 0.000, epsilon: 0.000, loss: 0.16004
# Epizod: 215/200000, średni reward z ostatnich 10 epizodów: 0.000, epsilon: 0.000, loss: 0.15466
# Epizod: 216/200000, średni reward z ostatnich 10 epizodów: 0.000, epsilon: 0.000, loss: 0.15761
# Epizod: 217/200000, średni reward z ostatnich 10 epizodów: 0.010, epsilon: 0.000, loss: 0.15419
# Epizod: 218/200000, średni reward z ostatnich 10 epizodów: 0.010, epsilon: 0.000, loss: 0.16024
# Epizod: 219/200000, średni reward z ostatnich 10 epizodów: -0.018, epsilon: 0.000, loss: 0.15074
# Epizod: 220/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.14623
# Epizod: 221/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.14932
# Epizod: 222/200000, średni reward z ostatnich 10 epizodów: -0.086, epsilon: 0.000, loss: 0.14602
# Epizod: 223/200000, średni reward z ostatnich 10 epizodów: -0.086, epsilon: 0.000, loss: 0.14837
# Epizod: 224/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.14621
# Epizod: 225/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.14458
# Epizod: 226/200000, średni reward z ostatnich 10 epizodów: -0.075, epsilon: 0.000, loss: 0.14571
# Epizod: 227/200000, średni reward z ostatnich 10 epizodów: -0.033, epsilon: 0.000, loss: 0.13959
# Epizod: 228/200000, średni reward z ostatnich 10 epizodów: -0.033, epsilon: 0.000, loss: 0.13253
# Epizod: 229/200000, średni reward z ostatnich 10 epizodów: -0.005, epsilon: 0.000, loss: 0.13775
# Epizod: 230/200000, średni reward z ostatnich 10 epizodów: 0.043, epsilon: 0.000, loss: 0.14219
# Epizod: 231/200000, średni reward z ostatnich 10 epizodów: -0.005, epsilon: 0.000, loss: 0.13803
# Epizod: 232/200000, średni reward z ostatnich 10 epizodów: -0.005, epsilon: 0.000, loss: 0.12991
# Epizod: 233/200000, średni reward z ostatnich 10 epizodów: -0.005, epsilon: 0.000, loss: 0.12957
# Epizod: 234/200000, średni reward z ostatnich 10 epizodów: -0.017, epsilon: 0.000, loss: 0.13313
# Epizod: 235/200000, średni reward z ostatnich 10 epizodów: 0.255, epsilon: 0.000, loss: 0.13619
# Epizod: 236/200000, średni reward z ostatnich 10 epizodów: 0.255, epsilon: 0.000, loss: 0.13186
# Epizod: 237/200000, średni reward z ostatnich 10 epizodów: 0.203, epsilon: 0.000, loss: 0.13412
# Epizod: 238/200000, średni reward z ostatnich 10 epizodów: 0.155, epsilon: 0.000, loss: 0.12497
# Epizod: 239/200000, średni reward z ostatnich 10 epizodów: 0.155, epsilon: 0.000, loss: 0.12822
# Epizod: 240/200000, średni reward z ostatnich 10 epizodów: 0.155, epsilon: 0.000, loss: 0.12403
# Epizod: 241/200000, średni reward z ostatnich 10 epizodów: 0.203, epsilon: 0.000, loss: 0.12850
# Epizod: 242/200000, średni reward z ostatnich 10 epizodów: 0.203, epsilon: 0.000, loss: 0.12158
# Epizod: 243/200000, średni reward z ostatnich 10 epizodów: 0.253, epsilon: 0.000, loss: 0.13116
# Epizod: 244/200000, średni reward z ostatnich 10 epizodów: 0.253, epsilon: 0.000, loss: 0.12153
# Epizod: 245/200000, średni reward z ostatnich 10 epizodów: -0.018, epsilon: 0.000, loss: 0.12943
# Epizod: 246/200000, średni reward z ostatnich 10 epizodów: 0.094, epsilon: 0.000, loss: 0.12228
# Epizod: 247/200000, średni reward z ostatnich 10 epizodów: 0.094, epsilon: 0.000, loss: 0.11862
# Epizod: 248/200000, średni reward z ostatnich 10 epizodów: 0.093, epsilon: 0.000, loss: 0.11893
# Epizod: 249/200000, średni reward z ostatnich 10 epizodów: 0.153, epsilon: 0.000, loss: 0.12240
# Epizod: 250/200000, średni reward z ostatnich 10 epizodów: 0.255, epsilon: 0.000, loss: 0.11901
# Epizod: 251/200000, średni reward z ostatnich 10 epizodów: 0.255, epsilon: 0.000, loss: 0.11583
# Epizod: 252/200000, średni reward z ostatnich 10 epizodów: 0.287, epsilon: 0.000, loss: 0.11630
# Epizod: 253/200000, średni reward z ostatnich 10 epizodów: 0.639, epsilon: 0.000, loss: 0.11782
# Epizod: 254/200000, średni reward z ostatnich 10 epizodów: 0.639, epsilon: 0.000, loss: 0.11395
# Epizod: 255/200000, średni reward z ostatnich 10 epizodów: 0.639, epsilon: 0.000, loss: 0.12233
# Epizod: 256/200000, średni reward z ostatnich 10 epizodów: 0.527, epsilon: 0.000, loss: 0.11229
# Epizod: 257/200000, średni reward z ostatnich 10 epizodów: 0.527, epsilon: 0.000, loss: 0.11421
# Epizod: 258/200000, średni reward z ostatnich 10 epizodów: 0.547, epsilon: 0.000, loss: 0.10777
# Epizod: 259/200000, średni reward z ostatnich 10 epizodów: 0.487, epsilon: 0.000, loss: 0.11126
# Epizod: 260/200000, średni reward z ostatnich 10 epizodów: 0.385, epsilon: 0.000, loss: 0.11693
# Epizod: 261/200000, średni reward z ostatnich 10 epizodów: 0.336, epsilon: 0.000, loss: 0.11618
# Epizod: 262/200000, średni reward z ostatnich 10 epizodów: 0.304, epsilon: 0.000, loss: 0.10874
# Epizod: 263/200000, średni reward z ostatnich 10 epizodów: -0.097, epsilon: 0.000, loss: 0.10687
# Epizod: 264/200000, średni reward z ostatnich 10 epizodów: -0.097, epsilon: 0.000, loss: 0.10165
# Epizod: 265/200000, średni reward z ostatnich 10 epizodów: -0.097, epsilon: 0.000, loss: 0.10811
# Epizod: 266/200000, średni reward z ostatnich 10 epizodów: -0.097, epsilon: 0.000, loss: 0.10754
# Epizod: 267/200000, średni reward z ostatnich 10 epizodów: -0.097, epsilon: 0.000, loss: 0.10526
# Epizod: 268/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 0.10557
# Epizod: 269/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 0.10084
# Epizod: 270/200000, średni reward z ostatnich 10 epizodów: 0.141, epsilon: 0.000, loss: 0.10348
# Epizod: 271/200000, średni reward z ostatnich 10 epizodów: 0.190, epsilon: 0.000, loss: 0.10128
# Epizod: 272/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.10089
# Epizod: 273/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.10302
# Epizod: 274/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.09855
# Epizod: 275/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.09787
# Epizod: 276/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.10634
# Epizod: 277/200000, średni reward z ostatnich 10 epizodów: 0.142, epsilon: 0.000, loss: 0.09637
# Epizod: 278/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.09444
# Epizod: 279/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.10142
# Epizod: 280/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.09903
# Epizod: 281/200000, średni reward z ostatnich 10 epizodów: -0.116, epsilon: 0.000, loss: 0.09766
# Epizod: 282/200000, średni reward z ostatnich 10 epizodów: -0.066, epsilon: 0.000, loss: 0.09078
# Epizod: 283/200000, średni reward z ostatnich 10 epizodów: -0.006, epsilon: 0.000, loss: 0.08854
# Epizod: 284/200000, średni reward z ostatnich 10 epizodów: 0.034, epsilon: 0.000, loss: 0.09262
# Epizod: 285/200000, średni reward z ostatnich 10 epizodów: 0.034, epsilon: 0.000, loss: 0.09247
# Epizod: 286/200000, średni reward z ostatnich 10 epizodów: 0.175, epsilon: 0.000, loss: 0.08778
# Epizod: 287/200000, średni reward z ostatnich 10 epizodów: 0.175, epsilon: 0.000, loss: 0.09093
# Epizod: 288/200000, średni reward z ostatnich 10 epizodów: 0.175, epsilon: 0.000, loss: 0.08631
# Epizod: 289/200000, średni reward z ostatnich 10 epizodów: 0.175, epsilon: 0.000, loss: 0.09325
# Epizod: 290/200000, średni reward z ostatnich 10 epizodów: 0.305, epsilon: 0.000, loss: 0.09130
# Epizod: 291/200000, średni reward z ostatnich 10 epizodów: 0.503, epsilon: 0.000, loss: 0.09200
# Epizod: 292/200000, średni reward z ostatnich 10 epizodów: 0.572, epsilon: 0.000, loss: 0.08455
# Epizod: 293/200000, średni reward z ostatnich 10 epizodów: 0.512, epsilon: 0.000, loss: 0.08739
# Epizod: 294/200000, średni reward z ostatnich 10 epizodów: 0.472, epsilon: 0.000, loss: 0.08490
# Epizod: 295/200000, średni reward z ostatnich 10 epizodów: 0.732, epsilon: 0.000, loss: 0.08618
# Epizod: 296/200000, średni reward z ostatnich 10 epizodów: 0.590, epsilon: 0.000, loss: 0.08566
# Epizod: 297/200000, średni reward z ostatnich 10 epizodów: 0.590, epsilon: 0.000, loss: 0.08044
# Epizod: 298/200000, średni reward z ostatnich 10 epizodów: 0.590, epsilon: 0.000, loss: 0.08520
# Epizod: 299/200000, średni reward z ostatnich 10 epizodów: 0.590, epsilon: 0.000, loss: 0.08309
# Epizod: 300/200000, średni reward z ostatnich 10 epizodów: 0.460, epsilon: 0.000, loss: 0.08240
# Epizod: 301/200000, średni reward z ostatnich 10 epizodów: 0.310, epsilon: 0.000, loss: 0.08437
# Epizod: 302/200000, średni reward z ostatnich 10 epizodów: 0.240, epsilon: 0.000, loss: 0.08360
# Epizod: 303/200000, średni reward z ostatnich 10 epizodów: 0.240, epsilon: 0.000, loss: 0.08285
# Epizod: 304/200000, średni reward z ostatnich 10 epizodów: 0.240, epsilon: 0.000, loss: 0.07863
# Epizod: 305/200000, średni reward z ostatnich 10 epizodów: -0.020, epsilon: 0.000, loss: 0.08157
# Epizod: 306/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.07948
# Epizod: 307/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.07904
# Epizod: 308/200000, średni reward z ostatnich 10 epizodów: 0.832, epsilon: 0.000, loss: 0.07664
# Epizod: 309/200000, średni reward z ostatnich 10 epizodów: 0.832, epsilon: 0.000, loss: 0.08444
# Epizod: 310/200000, średni reward z ostatnich 10 epizodów: 1.203, epsilon: 0.000, loss: 0.07478
# Epizod: 311/200000, średni reward z ostatnich 10 epizodów: 1.155, epsilon: 0.000, loss: 0.08072
# Epizod: 312/200000, średni reward z ostatnich 10 epizodów: 1.107, epsilon: 0.000, loss: 0.07428
# Epizod: 313/200000, średni reward z ostatnich 10 epizodów: 1.117, epsilon: 0.000, loss: 0.07481
# Epizod: 314/200000, średni reward z ostatnich 10 epizodów: 1.117, epsilon: 0.000, loss: 0.07466
# Epizod: 315/200000, średni reward z ostatnich 10 epizodów: 1.117, epsilon: 0.000, loss: 0.07302
# Epizod: 316/200000, średni reward z ostatnich 10 epizodów: 1.415, epsilon: 0.000, loss: 0.07358
# Epizod: 317/200000, średni reward z ostatnich 10 epizodów: 1.517, epsilon: 0.000, loss: 0.07660
# Epizod: 318/200000, średni reward z ostatnich 10 epizodów: 0.738, epsilon: 0.000, loss: 0.07565
# Epizod: 319/200000, średni reward z ostatnich 10 epizodów: 0.738, epsilon: 0.000, loss: 0.07214
# Epizod: 320/200000, średni reward z ostatnich 10 epizodów: 0.367, epsilon: 0.000, loss: 0.07237
# Epizod: 321/200000, średni reward z ostatnich 10 epizodów: 0.415, epsilon: 0.000, loss: 0.07296
# Epizod: 322/200000, średni reward z ostatnich 10 epizodów: 0.464, epsilon: 0.000, loss: 0.07245
# Epizod: 323/200000, średni reward z ostatnich 10 epizodów: 0.544, epsilon: 0.000, loss: 0.07358
# Epizod: 324/200000, średni reward z ostatnich 10 epizodów: 0.574, epsilon: 0.000, loss: 0.07212
# Epizod: 325/200000, średni reward z ostatnich 10 epizodów: 0.525, epsilon: 0.000, loss: 0.06477
# Epizod: 326/200000, średni reward z ostatnich 10 epizodów: 0.275, epsilon: 0.000, loss: 0.07026
# Epizod: 327/200000, średni reward z ostatnich 10 epizodów: 0.173, epsilon: 0.000, loss: 0.06863
# Epizod: 328/200000, średni reward z ostatnich 10 epizodów: 0.052, epsilon: 0.000, loss: 0.06649
# Epizod: 329/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.06718
# Epizod: 330/200000, średni reward z ostatnich 10 epizodów: 0.054, epsilon: 0.000, loss: 0.06902
# Epizod: 331/200000, średni reward z ostatnich 10 epizodów: 0.315, epsilon: 0.000, loss: 0.06662
# Epizod: 332/200000, średni reward z ostatnich 10 epizodów: 0.355, epsilon: 0.000, loss: 0.06499
# Epizod: 333/200000, średni reward z ostatnich 10 epizodów: 0.217, epsilon: 0.000, loss: 0.06654
# Epizod: 334/200000, średni reward z ostatnich 10 epizodów: 0.187, epsilon: 0.000, loss: 0.06587
# Epizod: 335/200000, średni reward z ostatnich 10 epizodów: 0.187, epsilon: 0.000, loss: 0.06490
# Epizod: 336/200000, średni reward z ostatnich 10 epizodów: 0.187, epsilon: 0.000, loss: 0.06908
# Epizod: 337/200000, średni reward z ostatnich 10 epizodów: 0.187, epsilon: 0.000, loss: 0.06682
# Epizod: 338/200000, średni reward z ostatnich 10 epizodów: 0.187, epsilon: 0.000, loss: 0.06505
# Epizod: 339/200000, średni reward z ostatnich 10 epizodów: 0.137, epsilon: 0.000, loss: 0.06788
# Epizod: 340/200000, średni reward z ostatnich 10 epizodów: 0.185, epsilon: 0.000, loss: 0.06478
# Epizod: 341/200000, średni reward z ostatnich 10 epizodów: -0.076, epsilon: 0.000, loss: 0.06137
# Epizod: 342/200000, średni reward z ostatnich 10 epizodów: -0.116, epsilon: 0.000, loss: 0.06661
# Epizod: 343/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.06254
# Epizod: 344/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.06056
# Epizod: 345/200000, średni reward z ostatnich 10 epizodów: 0.260, epsilon: 0.000, loss: 0.06320
# Epizod: 346/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.06440
# Epizod: 347/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.05652
# Epizod: 348/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.05805
# Epizod: 349/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.05996
# Epizod: 350/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.05727
# Epizod: 351/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.06319
# Epizod: 352/200000, średni reward z ostatnich 10 epizodów: 0.212, epsilon: 0.000, loss: 0.05745
# Epizod: 353/200000, średni reward z ostatnich 10 epizodów: 0.164, epsilon: 0.000, loss: 0.06156
# Epizod: 354/200000, średni reward z ostatnich 10 epizodów: 0.084, epsilon: 0.000, loss: 0.05556
# Epizod: 355/200000, średni reward z ostatnich 10 epizodów: 0.035, epsilon: 0.000, loss: 0.05686
# Epizod: 356/200000, średni reward z ostatnich 10 epizodów: 0.084, epsilon: 0.000, loss: 0.05877
# Epizod: 357/200000, średni reward z ostatnich 10 epizodów: 0.135, epsilon: 0.000, loss: 0.05918
# Epizod: 358/200000, średni reward z ostatnich 10 epizodów: 0.135, epsilon: 0.000, loss: 0.05756
# Epizod: 359/200000, średni reward z ostatnich 10 epizodów: 0.087, epsilon: 0.000, loss: 0.05840
# Epizod: 360/200000, średni reward z ostatnich 10 epizodów: 0.087, epsilon: 0.000, loss: 0.05651
# Epizod: 361/200000, średni reward z ostatnich 10 epizodów: 0.117, epsilon: 0.000, loss: 0.05803
# Epizod: 362/200000, średni reward z ostatnich 10 epizodów: 0.117, epsilon: 0.000, loss: 0.05412
# Epizod: 363/200000, średni reward z ostatnich 10 epizodów: 0.335, epsilon: 0.000, loss: 0.05407
# Epizod: 364/200000, średni reward z ostatnich 10 epizodów: 0.295, epsilon: 0.000, loss: 0.05558
# Epizod: 365/200000, średni reward z ostatnich 10 epizodów: 0.344, epsilon: 0.000, loss: 0.05671
# Epizod: 366/200000, średni reward z ostatnich 10 epizodów: 0.344, epsilon: 0.000, loss: 0.05425
# Epizod: 367/200000, średni reward z ostatnich 10 epizodów: 0.292, epsilon: 0.000, loss: 0.05697
# Epizod: 368/200000, średni reward z ostatnich 10 epizodów: 0.292, epsilon: 0.000, loss: 0.05505
# Epizod: 369/200000, średni reward z ostatnich 10 epizodów: 0.370, epsilon: 0.000, loss: 0.05000
# Epizod: 370/200000, średni reward z ostatnich 10 epizodów: 0.370, epsilon: 0.000, loss: 0.05374
# Epizod: 371/200000, średni reward z ostatnich 10 epizodów: 0.342, epsilon: 0.000, loss: 0.04958
# Epizod: 372/200000, średni reward z ostatnich 10 epizodów: 0.342, epsilon: 0.000, loss: 0.04962
# Epizod: 373/200000, średni reward z ostatnich 10 epizodów: 0.172, epsilon: 0.000, loss: 0.05050
# Epizod: 374/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.05344
# Epizod: 375/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.05395
# Epizod: 376/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.05594
# Epizod: 377/200000, średni reward z ostatnich 10 epizodów: 0.022, epsilon: 0.000, loss: 0.04954
# Epizod: 378/200000, średni reward z ostatnich 10 epizodów: 0.194, epsilon: 0.000, loss: 0.05113
# Epizod: 379/200000, średni reward z ostatnich 10 epizodów: 0.164, epsilon: 0.000, loss: 0.05273
# Epizod: 380/200000, średni reward z ostatnich 10 epizodów: 0.164, epsilon: 0.000, loss: 0.05400
# Epizod: 381/200000, średni reward z ostatnich 10 epizodów: 0.162, epsilon: 0.000, loss: 0.05234
# Epizod: 382/200000, średni reward z ostatnich 10 epizodów: 0.162, epsilon: 0.000, loss: 0.05043
# Epizod: 383/200000, średni reward z ostatnich 10 epizodów: 0.192, epsilon: 0.000, loss: 0.05047
# Epizod: 384/200000, średni reward z ostatnich 10 epizodów: 0.182, epsilon: 0.000, loss: 0.05199
# Epizod: 385/200000, średni reward z ostatnich 10 epizodów: 0.182, epsilon: 0.000, loss: 0.05078
# Epizod: 386/200000, średni reward z ostatnich 10 epizodów: 0.182, epsilon: 0.000, loss: 0.05109
# Epizod: 387/200000, średni reward z ostatnich 10 epizodów: 0.182, epsilon: 0.000, loss: 0.04963
# Epizod: 388/200000, średni reward z ostatnich 10 epizodów: 0.012, epsilon: 0.000, loss: 0.04882
# Epizod: 389/200000, średni reward z ostatnich 10 epizodów: 0.012, epsilon: 0.000, loss: 0.04812
# Epizod: 390/200000, średni reward z ostatnich 10 epizodów: 0.082, epsilon: 0.000, loss: 0.04933
# Epizod: 391/200000, średni reward z ostatnich 10 epizodów: 0.082, epsilon: 0.000, loss: 0.04552
# Epizod: 392/200000, średni reward z ostatnich 10 epizodów: 0.082, epsilon: 0.000, loss: 0.04789
# Epizod: 393/200000, średni reward z ostatnich 10 epizodów: 0.052, epsilon: 0.000, loss: 0.04940
# Epizod: 394/200000, średni reward z ostatnich 10 epizodów: 0.192, epsilon: 0.000, loss: 0.04451
# Epizod: 395/200000, średni reward z ostatnich 10 epizodów: 0.244, epsilon: 0.000, loss: 0.04655
# Epizod: 396/200000, średni reward z ostatnich 10 epizodów: 0.244, epsilon: 0.000, loss: 0.04814
# Epizod: 397/200000, średni reward z ostatnich 10 epizodów: 0.244, epsilon: 0.000, loss: 0.04701
# Epizod: 398/200000, średni reward z ostatnich 10 epizodów: 0.373, epsilon: 0.000, loss: 0.05029
# Epizod: 399/200000, średni reward z ostatnich 10 epizodów: 0.533, epsilon: 0.000, loss: 0.04832
# Epizod: 400/200000, średni reward z ostatnich 10 epizodów: 0.463, epsilon: 0.000, loss: 0.04608
# Epizod: 401/200000, średni reward z ostatnich 10 epizodów: 0.463, epsilon: 0.000, loss: 0.04701
# Epizod: 402/200000, średni reward z ostatnich 10 epizodów: 0.463, epsilon: 0.000, loss: 0.04449
# Epizod: 403/200000, średni reward z ostatnich 10 epizodów: 0.495, epsilon: 0.000, loss: 0.04571
# Epizod: 404/200000, średni reward z ostatnich 10 epizodów: 0.355, epsilon: 0.000, loss: 0.04609
# Epizod: 405/200000, średni reward z ostatnich 10 epizodów: 0.793, epsilon: 0.000, loss: 0.04487
# Epizod: 406/200000, średni reward z ostatnich 10 epizodów: 0.793, epsilon: 0.000, loss: 0.04557
# Epizod: 407/200000, średni reward z ostatnich 10 epizodów: 0.793, epsilon: 0.000, loss: 0.04282
# Epizod: 408/200000, średni reward z ostatnich 10 epizodów: 1.062, epsilon: 0.000, loss: 0.04298
# Epizod: 409/200000, średni reward z ostatnich 10 epizodów: 0.902, epsilon: 0.000, loss: 0.04339
# Epizod: 410/200000, średni reward z ostatnich 10 epizodów: 0.854, epsilon: 0.000, loss: 0.04384
# Epizod: 411/200000, średni reward z ostatnich 10 epizodów: 0.854, epsilon: 0.000, loss: 0.04410
# Epizod: 412/200000, średni reward z ostatnich 10 epizodów: 1.084, epsilon: 0.000, loss: 0.04267
# Epizod: 413/200000, średni reward z ostatnich 10 epizodów: 1.004, epsilon: 0.000, loss: 0.04301
# Epizod: 414/200000, średni reward z ostatnich 10 epizodów: 1.004, epsilon: 0.000, loss: 0.04378
# Epizod: 415/200000, średni reward z ostatnich 10 epizodów: 0.514, epsilon: 0.000, loss: 0.04331
# Epizod: 416/200000, średni reward z ostatnich 10 epizodów: 0.514, epsilon: 0.000, loss: 0.04316
# Epizod: 417/200000, średni reward z ostatnich 10 epizodów: 0.466, epsilon: 0.000, loss: 0.04136
# Epizod: 418/200000, średni reward z ostatnich 10 epizodów: 0.066, epsilon: 0.000, loss: 0.04245
# Epizod: 419/200000, średni reward z ostatnich 10 epizodów: 0.066, epsilon: 0.000, loss: 0.04225
# Epizod: 420/200000, średni reward z ostatnich 10 epizodów: 0.114, epsilon: 0.000, loss: 0.04266
# Epizod: 421/200000, średni reward z ostatnich 10 epizodów: 0.114, epsilon: 0.000, loss: 0.04292
# Epizod: 422/200000, średni reward z ostatnich 10 epizodów: -0.116, epsilon: 0.000, loss: 0.04113
# Epizod: 423/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.04299
# Epizod: 424/200000, średni reward z ostatnich 10 epizodów: -0.068, epsilon: 0.000, loss: 0.04060
# Epizod: 425/200000, średni reward z ostatnich 10 epizodów: 0.313, epsilon: 0.000, loss: 0.04113
# Epizod: 426/200000, średni reward z ostatnich 10 epizodów: 0.313, epsilon: 0.000, loss: 0.04013
# Epizod: 427/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04051
# Epizod: 428/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04105
# Epizod: 429/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04153
# Epizod: 430/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04093
# Epizod: 431/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04076
# Epizod: 432/200000, średni reward z ostatnich 10 epizodów: 0.361, epsilon: 0.000, loss: 0.04050
# Epizod: 433/200000, średni reward z ostatnich 10 epizodów: 0.393, epsilon: 0.000, loss: 0.04224
# Epizod: 434/200000, średni reward z ostatnich 10 epizodów: 0.393, epsilon: 0.000, loss: 0.03871
# Epizod: 435/200000, średni reward z ostatnich 10 epizodów: 0.252, epsilon: 0.000, loss: 0.04240
# Epizod: 436/200000, średni reward z ostatnich 10 epizodów: 0.204, epsilon: 0.000, loss: 0.04041
# Epizod: 437/200000, średni reward z ostatnich 10 epizodów: 0.204, epsilon: 0.000, loss: 0.04075
# Epizod: 438/200000, średni reward z ostatnich 10 epizodów: 0.204, epsilon: 0.000, loss: 0.04095
# Epizod: 439/200000, średni reward z ostatnich 10 epizodów: 0.204, epsilon: 0.000, loss: 0.03734
# Epizod: 440/200000, średni reward z ostatnich 10 epizodów: 0.156, epsilon: 0.000, loss: 0.03895
# Epizod: 441/200000, średni reward z ostatnich 10 epizodów: 0.156, epsilon: 0.000, loss: 0.04202
# Epizod: 442/200000, średni reward z ostatnich 10 epizodów: 0.246, epsilon: 0.000, loss: 0.04011
# Epizod: 443/200000, średni reward z ostatnich 10 epizodów: 0.294, epsilon: 0.000, loss: 0.03898
# Epizod: 444/200000, średni reward z ostatnich 10 epizodów: 0.294, epsilon: 0.000, loss: 0.03822
# Epizod: 445/200000, średni reward z ostatnich 10 epizodów: 0.054, epsilon: 0.000, loss: 0.03733
# Epizod: 446/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03927
# Epizod: 447/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.04021
# Epizod: 448/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03929
# Epizod: 449/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03838
# Epizod: 450/200000, średni reward z ostatnich 10 epizodów: 0.150, epsilon: 0.000, loss: 0.04005
# Epizod: 451/200000, średni reward z ostatnich 10 epizodów: 0.150, epsilon: 0.000, loss: 0.03915
# Epizod: 452/200000, średni reward z ostatnich 10 epizodów: 0.060, epsilon: 0.000, loss: 0.03788
# Epizod: 453/200000, średni reward z ostatnich 10 epizodów: -0.020, epsilon: 0.000, loss: 0.03648
# Epizod: 454/200000, średni reward z ostatnich 10 epizodów: -0.020, epsilon: 0.000, loss: 0.03877
# Epizod: 455/200000, średni reward z ostatnich 10 epizodów: -0.020, epsilon: 0.000, loss: 0.03824
# Epizod: 456/200000, średni reward z ostatnich 10 epizodów: -0.020, epsilon: 0.000, loss: 0.03693
# Epizod: 457/200000, średni reward z ostatnich 10 epizodów: 0.150, epsilon: 0.000, loss: 0.03779
# Epizod: 458/200000, średni reward z ostatnich 10 epizodów: 0.150, epsilon: 0.000, loss: 0.03698
# Epizod: 459/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03883
# Epizod: 460/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03731
# Epizod: 461/200000, średni reward z ostatnich 10 epizodów: 0.102, epsilon: 0.000, loss: 0.03683
# Epizod: 462/200000, średni reward z ostatnich 10 epizodów: 0.322, epsilon: 0.000, loss: 0.03617
# Epizod: 463/200000, średni reward z ostatnich 10 epizodów: 0.322, epsilon: 0.000, loss: 0.03750
# Epizod: 464/200000, średni reward z ostatnich 10 epizodów: 1.252, epsilon: 0.000, loss: 0.03542
# Epizod: 465/200000, średni reward z ostatnich 10 epizodów: 1.352, epsilon: 0.000, loss: 0.03362
# Epizod: 466/200000, średni reward z ostatnich 10 epizodów: 1.352, epsilon: 0.000, loss: 0.03687
# Epizod: 467/200000, średni reward z ostatnich 10 epizodów: 1.182, epsilon: 0.000, loss: 0.03663
# Epizod: 468/200000, średni reward z ostatnich 10 epizodów: 1.182, epsilon: 0.000, loss: 0.03590
# Epizod: 469/200000, średni reward z ostatnich 10 epizodów: 1.230, epsilon: 0.000, loss: 0.03531
# Epizod: 470/200000, średni reward z ostatnich 10 epizodów: 2.310, epsilon: 0.000, loss: 0.03385
# Epizod: 471/200000, średni reward z ostatnich 10 epizodów: 2.310, epsilon: 0.000, loss: 0.03776
# Epizod: 472/200000, średni reward z ostatnich 10 epizodów: 2.090, epsilon: 0.000, loss: 0.03545
# Epizod: 473/200000, średni reward z ostatnich 10 epizodów: 2.310, epsilon: 0.000, loss: 0.03468
# Epizod: 474/200000, średni reward z ostatnich 10 epizodów: 1.332, epsilon: 0.000, loss: 0.03311
# Epizod: 475/200000, średni reward z ostatnich 10 epizodów: 1.232, epsilon: 0.000, loss: 0.03440
# Epizod: 476/200000, średni reward z ostatnich 10 epizodów: 1.232, epsilon: 0.000, loss: 0.03743
# Epizod: 477/200000, średni reward z ostatnich 10 epizodów: 1.232, epsilon: 0.000, loss: 0.03428
# Epizod: 478/200000, średni reward z ostatnich 10 epizodów: 1.184, epsilon: 0.000, loss: 0.03680
# Epizod: 479/200000, średni reward z ostatnich 10 epizodów: 1.184, epsilon: 0.000, loss: 0.03579
# Epizod: 480/200000, średni reward z ostatnich 10 epizodów: 0.104, epsilon: 0.000, loss: 0.03432
# Epizod: 481/200000, średni reward z ostatnich 10 epizodów: 0.104, epsilon: 0.000, loss: 0.03566
# Epizod: 482/200000, średni reward z ostatnich 10 epizodów: 0.056, epsilon: 0.000, loss: 0.03338
# Epizod: 483/200000, średni reward z ostatnich 10 epizodów: -0.164, epsilon: 0.000, loss: 0.03317
# Epizod: 484/200000, średni reward z ostatnich 10 epizodów: -0.116, epsilon: 0.000, loss: 0.03484
# Epizod: 485/200000, średni reward z ostatnich 10 epizodów: -0.144, epsilon: 0.000, loss: 0.03296
# Epizod: 486/200000, średni reward z ostatnich 10 epizodów: -0.144, epsilon: 0.000, loss: 0.03332
# Epizod: 487/200000, średni reward z ostatnich 10 epizodów: -0.144, epsilon: 0.000, loss: 0.03578
# Epizod: 488/200000, średni reward z ostatnich 10 epizodów: -0.064, epsilon: 0.000, loss: 0.03607
# Epizod: 489/200000, średni reward z ostatnich 10 epizodów: -0.112, epsilon: 0.000, loss: 0.03529
# Epizod: 490/200000, średni reward z ostatnich 10 epizodów: -0.112, epsilon: 0.000, loss: 0.03255
# Epizod: 491/200000, średni reward z ostatnich 10 epizodów: 0.218, epsilon: 0.000, loss: 0.03392
# Epizod: 492/200000, średni reward z ostatnich 10 epizodów: 0.266, epsilon: 0.000, loss: 0.03273
# Epizod: 493/200000, średni reward z ostatnich 10 epizodów: 0.266, epsilon: 0.000, loss: 0.03242
# Epizod: 494/200000, średni reward z ostatnich 10 epizodów: 0.736, epsilon: 0.000, loss: 0.03315
# Epizod: 495/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 0.03497
# Epizod: 496/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 0.03187
# Epizod: 497/200000, średni reward z ostatnich 10 epizodów: 0.715, epsilon: 0.000, loss: 0.03461
# Epizod: 498/200000, średni reward z ostatnich 10 epizodów: 0.684, epsilon: 0.000, loss: 0.03296
# Epizod: 499/200000, średni reward z ostatnich 10 epizodów: 0.753, epsilon: 0.000, loss: 0.03235
# Epizod: 500/200000, średni reward z ostatnich 10 epizodów: 1.063, epsilon: 0.000, loss: 0.03228
# ...
# Epizod: 6278/200000, średni reward z ostatnich 10 epizodów: 2.586, epsilon: 0.000, loss: 0.00132
# Epizod: 6279/200000, średni reward z ostatnich 10 epizodów: 3.186, epsilon: 0.000, loss: 0.00113
# Epizod: 6280/200000, średni reward z ostatnich 10 epizodów: 3.336, epsilon: 0.000, loss: 0.00111
# Epizod: 6281/200000, średni reward z ostatnich 10 epizodów: 2.506, epsilon: 0.000, loss: 0.00124
# Epizod: 6282/200000, średni reward z ostatnich 10 epizodów: 2.376, epsilon: 0.000, loss: 0.00111
# Epizod: 6283/200000, średni reward z ostatnich 10 epizodów: 2.016, epsilon: 0.000, loss: 0.00111
# Epizod: 6284/200000, średni reward z ostatnich 10 epizodów: 2.174, epsilon: 0.000, loss: 0.00107
# Epizod: 6285/200000, średni reward z ostatnich 10 epizodów: 2.372, epsilon: 0.000, loss: 0.00113
# Epizod: 6286/200000, średni reward z ostatnich 10 epizodów: 2.162, epsilon: 0.000, loss: 0.00118
# Epizod: 6287/200000, średni reward z ostatnich 10 epizodów: 2.702, epsilon: 0.000, loss: 0.00125
# Epizod: 6288/200000, średni reward z ostatnich 10 epizodów: 2.750, epsilon: 0.000, loss: 0.00115
# Epizod: 6289/200000, średni reward z ostatnich 10 epizodów: 1.820, epsilon: 0.000, loss: 0.00112
# Epizod: 6290/200000, średni reward z ostatnich 10 epizodów: 1.490, epsilon: 0.000, loss: 0.00129
# Epizod: 6291/200000, średni reward z ostatnich 10 epizodów: 1.482, epsilon: 0.000, loss: 0.00123
# Epizod: 6292/200000, średni reward z ostatnich 10 epizodów: 2.242, epsilon: 0.000, loss: 0.00121
# Epizod: 6293/200000, średni reward z ostatnich 10 epizodów: 2.992, epsilon: 0.000, loss: 0.00130
# Epizod: 6294/200000, średni reward z ostatnich 10 epizodów: 2.954, epsilon: 0.000, loss: 0.00107
# Epizod: 6295/200000, średni reward z ostatnich 10 epizodów: 2.694, epsilon: 0.000, loss: 0.00126
# Epizod: 6296/200000, średni reward z ostatnich 10 epizodów: 2.804, epsilon: 0.000, loss: 0.00112
# Epizod: 6297/200000, średni reward z ostatnich 10 epizodów: 2.374, epsilon: 0.000, loss: 0.00111
# Epizod: 6298/200000, średni reward z ostatnich 10 epizodów: 2.374, epsilon: 0.000, loss: 0.00105
# Epizod: 6299/200000, średni reward z ostatnich 10 epizodów: 2.564, epsilon: 0.000, loss: 0.00128
# Epizod: 6300/200000, średni reward z ostatnich 10 epizodów: 2.634, epsilon: 0.000, loss: 0.00104
# Epizod: 6301/200000, średni reward z ostatnich 10 epizodów: 3.613, epsilon: 0.000, loss: 0.00106
# Epizod: 6302/200000, średni reward z ostatnich 10 epizodów: 3.063, epsilon: 0.000, loss: 0.00110
# Epizod: 6303/200000, średni reward z ostatnich 10 epizodów: 2.812, epsilon: 0.000, loss: 0.00103
# Epizod: 6304/200000, średni reward z ostatnich 10 epizodów: 3.431, epsilon: 0.000, loss: 0.00106
# Epizod: 6305/200000, średni reward z ostatnich 10 epizodów: 3.411, epsilon: 0.000, loss: 0.00105
# Epizod: 6306/200000, średni reward z ostatnich 10 epizodów: 3.111, epsilon: 0.000, loss: 0.00121
# Epizod: 6307/200000, średni reward z ostatnich 10 epizodów: 3.331, epsilon: 0.000, loss: 0.00105
# Epizod: 6308/200000, średni reward z ostatnich 10 epizodów: 3.331, epsilon: 0.000, loss: 0.00117
# Epizod: 6309/200000, średni reward z ostatnich 10 epizodów: 3.611, epsilon: 0.000, loss: 0.00127
# Epizod: 6310/200000, średni reward z ostatnich 10 epizodów: 3.471, epsilon: 0.000, loss: 0.00113
# Epizod: 6311/200000, średni reward z ostatnich 10 epizodów: 2.541, epsilon: 0.000, loss: 0.00116
# Epizod: 6312/200000, średni reward z ostatnich 10 epizodów: 2.211, epsilon: 0.000, loss: 0.00094
# Epizod: 6313/200000, średni reward z ostatnich 10 epizodów: 1.731, epsilon: 0.000, loss: 0.00116
# Epizod: 6314/200000, średni reward z ostatnich 10 epizodów: 1.191, epsilon: 0.000, loss: 0.00114
# Epizod: 6315/200000, średni reward z ostatnich 10 epizodów: 2.191, epsilon: 0.000, loss: 0.00108
# Epizod: 6316/200000, średni reward z ostatnich 10 epizodów: 2.651, epsilon: 0.000, loss: 0.00126
# Epizod: 6317/200000, średni reward z ostatnich 10 epizodów: 2.273, epsilon: 0.000, loss: 0.00123
# Epizod: 6318/200000, średni reward z ostatnich 10 epizodów: 2.525, epsilon: 0.000, loss: 0.00099
# Epizod: 6319/200000, średni reward z ostatnich 10 epizodów: 2.776, epsilon: 0.000, loss: 0.00106
# Epizod: 6320/200000, średni reward z ostatnich 10 epizodów: 2.776, epsilon: 0.000, loss: 0.00114
# Epizod: 6321/200000, średni reward z ostatnich 10 epizodów: 2.816, epsilon: 0.000, loss: 0.00116
# Epizod: 6322/200000, średni reward z ostatnich 10 epizodów: 2.816, epsilon: 0.000, loss: 0.00122
# Epizod: 6323/200000, średni reward z ostatnich 10 epizodów: 3.246, epsilon: 0.000, loss: 0.00115
# Epizod: 6324/200000, średni reward z ostatnich 10 epizodów: 3.395, epsilon: 0.000, loss: 0.00123
# Epizod: 6325/200000, średni reward z ostatnich 10 epizodów: 2.505, epsilon: 0.000, loss: 0.00105
# Epizod: 6326/200000, średni reward z ostatnich 10 epizodów: 1.985, epsilon: 0.000, loss: 0.00114
# Epizod: 6327/200000, średni reward z ostatnich 10 epizodów: 3.073, epsilon: 0.000, loss: 0.00107
# Epizod: 6328/200000, średni reward z ostatnich 10 epizodów: 2.821, epsilon: 0.000, loss: 0.00132
# Epizod: 6329/200000, średni reward z ostatnich 10 epizodów: 2.090, epsilon: 0.000, loss: 0.00110
# Epizod: 6330/200000, średni reward z ostatnich 10 epizodów: 2.120, epsilon: 0.000, loss: 0.00122
# Epizod: 6331/200000, średni reward z ostatnich 10 epizodów: 2.220, epsilon: 0.000, loss: 0.00115
# Epizod: 6332/200000, średni reward z ostatnich 10 epizodów: 3.170, epsilon: 0.000, loss: 0.00103
# Epizod: 6333/200000, średni reward z ostatnich 10 epizodów: 2.700, epsilon: 0.000, loss: 0.00111
# Epizod: 6334/200000, średni reward z ostatnich 10 epizodów: 2.760, epsilon: 0.000, loss: 0.00102
# Epizod: 6335/200000, średni reward z ostatnich 10 epizodów: 2.650, epsilon: 0.000, loss: 0.00124
# Epizod: 6336/200000, średni reward z ostatnich 10 epizodów: 2.750, epsilon: 0.000, loss: 0.00113
# Epizod: 6337/200000, średni reward z ostatnich 10 epizodów: 2.050, epsilon: 0.000, loss: 0.00122
# Epizod: 6338/200000, średni reward z ostatnich 10 epizodów: 2.380, epsilon: 0.000, loss: 0.00104
# Epizod: 6339/200000, średni reward z ostatnich 10 epizodów: 2.762, epsilon: 0.000, loss: 0.00119
# Epizod: 6340/200000, średni reward z ostatnich 10 epizodów: 2.674, epsilon: 0.000, loss: 0.00112
# Epizod: 6341/200000, średni reward z ostatnich 10 epizodów: 2.414, epsilon: 0.000, loss: 0.00121
# Epizod: 6342/200000, średni reward z ostatnich 10 epizodów: 1.464, epsilon: 0.000, loss: 0.00097
# Epizod: 6343/200000, średni reward z ostatnich 10 epizodów: 1.405, epsilon: 0.000, loss: 0.00114
# Epizod: 6344/200000, średni reward z ostatnich 10 epizodów: 2.155, epsilon: 0.000, loss: 0.00108
# Epizod: 6345/200000, średni reward z ostatnich 10 epizodów: 2.647, epsilon: 0.000, loss: 0.00111
# Epizod: 6346/200000, średni reward z ostatnich 10 epizodów: 2.539, epsilon: 0.000, loss: 0.00117
# Epizod: 6347/200000, średni reward z ostatnich 10 epizodów: 2.309, epsilon: 0.000, loss: 0.00108
# Epizod: 6348/200000, średni reward z ostatnich 10 epizodów: 2.089, epsilon: 0.000, loss: 0.00106
# Epizod: 6349/200000, średni reward z ostatnich 10 epizodów: 1.659, epsilon: 0.000, loss: 0.00106
# Epizod: 6350/200000, średni reward z ostatnich 10 epizodów: 1.659, epsilon: 0.000, loss: 0.00117
# Epizod: 6351/200000, średni reward z ostatnich 10 epizodów: 1.649, epsilon: 0.000, loss: 0.00111
# Epizod: 6352/200000, średni reward z ostatnich 10 epizodów: 1.649, epsilon: 0.000, loss: 0.00118
# Epizod: 6353/200000, średni reward z ostatnich 10 epizodów: 2.447, epsilon: 0.000, loss: 0.00130
# Epizod: 6354/200000, średni reward z ostatnich 10 epizodów: 1.337, epsilon: 0.000, loss: 0.00114
# Epizod: 6355/200000, średni reward z ostatnich 10 epizodów: 0.976, epsilon: 0.000, loss: 0.00113
# Epizod: 6356/200000, średni reward z ostatnich 10 epizodów: 0.984, epsilon: 0.000, loss: 0.00120
# Epizod: 6357/200000, średni reward z ostatnich 10 epizodów: 0.874, epsilon: 0.000, loss: 0.00105
# Epizod: 6358/200000, średni reward z ostatnich 10 epizodów: 1.904, epsilon: 0.000, loss: 0.00114
# Epizod: 6359/200000, średni reward z ostatnich 10 epizodów: 1.972, epsilon: 0.000, loss: 0.00106
# Epizod: 6360/200000, średni reward z ostatnich 10 epizodów: 2.251, epsilon: 0.000, loss: 0.00095
# Epizod: 6361/200000, średni reward z ostatnich 10 epizodów: 2.251, epsilon: 0.000, loss: 0.00131
# Epizod: 6362/200000, średni reward z ostatnich 10 epizodów: 2.251, epsilon: 0.000, loss: 0.00102
# Epizod: 6363/200000, średni reward z ostatnich 10 epizodów: 1.501, epsilon: 0.000, loss: 0.00108
# Epizod: 6364/200000, średni reward z ostatnich 10 epizodów: 1.453, epsilon: 0.000, loss: 0.00122
# Epizod: 6365/200000, średni reward z ostatnich 10 epizodów: 1.275, epsilon: 0.000, loss: 0.00123
# Epizod: 6366/200000, średni reward z ostatnich 10 epizodów: 1.275, epsilon: 0.000, loss: 0.00122
# Epizod: 6367/200000, średni reward z ostatnich 10 epizodów: 1.227, epsilon: 0.000, loss: 0.00124
# Epizod: 6368/200000, średni reward z ostatnich 10 epizodów: 0.087, epsilon: 0.000, loss: 0.00110
# Epizod: 6369/200000, średni reward z ostatnich 10 epizodów: 0.067, epsilon: 0.000, loss: 0.00105
# Epizod: 6370/200000, średni reward z ostatnich 10 epizodów: 0.226, epsilon: 0.000, loss: 0.00116
# Epizod: 6371/200000, średni reward z ostatnich 10 epizodów: 0.226, epsilon: 0.000, loss: 0.00110
# Epizod: 6372/200000, średni reward z ostatnich 10 epizodów: 0.456, epsilon: 0.000, loss: 0.00118
# Epizod: 6373/200000, średni reward z ostatnich 10 epizodów: 0.558, epsilon: 0.000, loss: 0.00112
# Epizod: 6374/200000, średni reward z ostatnich 10 epizodów: 0.606, epsilon: 0.000, loss: 0.00108
# Epizod: 6375/200000, średni reward z ostatnich 10 epizodów: 0.694, epsilon: 0.000, loss: 0.00107
# Epizod: 6376/200000, średni reward z ostatnich 10 epizodów: 0.676, epsilon: 0.000, loss: 0.00109
# Epizod: 6377/200000, średni reward z ostatnich 10 epizodów: 0.744, epsilon: 0.000, loss: 0.00110
# Epizod: 6378/200000, średni reward z ostatnich 10 epizodów: 0.744, epsilon: 0.000, loss: 0.00134
# Epizod: 6379/200000, średni reward z ostatnich 10 epizodów: 0.814, epsilon: 0.000, loss: 0.00092
# Epizod: 6380/200000, średni reward z ostatnich 10 epizodów: 0.734, epsilon: 0.000, loss: 0.00107
# Epizod: 6381/200000, średni reward z ostatnich 10 epizodów: 0.744, epsilon: 0.000, loss: 0.00115
# Epizod: 6382/200000, średni reward z ostatnich 10 epizodów: 0.514, epsilon: 0.000, loss: 0.00114
# Epizod: 6383/200000, średni reward z ostatnich 10 epizodów: 1.312, epsilon: 0.000, loss: 0.00109
# Epizod: 6384/200000, średni reward z ostatnich 10 epizodów: 1.312, epsilon: 0.000, loss: 0.00102
# Epizod: 6385/200000, średni reward z ostatnich 10 epizodów: 1.224, epsilon: 0.000, loss: 0.00111
# Epizod: 6386/200000, średni reward z ostatnich 10 epizodów: 1.194, epsilon: 0.000, loss: 0.00112
# Epizod: 6387/200000, średni reward z ostatnich 10 epizodów: 1.694, epsilon: 0.000, loss: 0.00110
# Epizod: 6388/200000, średni reward z ostatnich 10 epizodów: 1.854, epsilon: 0.000, loss: 0.00115
# Epizod: 6389/200000, średni reward z ostatnich 10 epizodów: 1.984, epsilon: 0.000, loss: 0.00123
# Epizod: 6390/200000, średni reward z ostatnich 10 epizodów: 2.564, epsilon: 0.000, loss: 0.00109
# Epizod: 6391/200000, średni reward z ostatnich 10 epizodów: 2.784, epsilon: 0.000, loss: 0.00107
# Epizod: 6392/200000, średni reward z ostatnich 10 epizodów: 3.674, epsilon: 0.000, loss: 0.00121
# Epizod: 6393/200000, średni reward z ostatnich 10 epizodów: 3.234, epsilon: 0.000, loss: 0.00114
# Epizod: 6394/200000, średni reward z ostatnich 10 epizodów: 3.234, epsilon: 0.000, loss: 0.00115
# Epizod: 6395/200000, średni reward z ostatnich 10 epizodów: 3.234, epsilon: 0.000, loss: 0.00105
# Epizod: 6396/200000, średni reward z ostatnich 10 epizodów: 4.292, epsilon: 0.000, loss: 0.00147
# Epizod: 6397/200000, średni reward z ostatnich 10 epizodów: 4.002, epsilon: 0.000, loss: 0.00123
# Epizod: 6398/200000, średni reward z ostatnich 10 epizodów: 4.213, epsilon: 0.000, loss: 0.00113
# Epizod: 6399/200000, średni reward z ostatnich 10 epizodów: 4.013, epsilon: 0.000, loss: 0.00103
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [22], line 86
#      84     action = np.random.randint(action_size)
#      85 else:
# ---> 86     q_values = q_network.predict(obs[np.newaxis, :], verbose=0)
#      87     action = np.argmax(q_values[0])
#      89 # Step w środowisku => dostajemy next_obs (5D)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py:559, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     557 outputs = None
#     558 with epoch_iterator.catch_stop_iteration():
# --> 559     for step, iterator in epoch_iterator:
#     560         callbacks.on_predict_batch_begin(step)
#     561         data = get_data(iterator)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\backend\tensorflow\trainer.py:736, in TFEpochIterator.__next__(self)
#     735 def __next__(self):
# --> 736     return next(self._epoch_iterator)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\keras\src\trainers\epoch_iterator.py:102, in EpochIterator._enumerate_iterator(self)
#     100 if steps_per_epoch > 0:
#     101     if self._current_iterator is None or self.steps_per_epoch is None:
# --> 102         self._current_iterator = iter(self._get_iterator())
#     103         self._steps_seen = 0
#     104     for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\data\ops\dataset_ops.py:501, in DatasetV2.__iter__(self)
#     499 if context.executing_eagerly() or ops.inside_function():
#     500   with ops.colocate_with(self._variant_tensor):
# --> 501     return iterator_ops.OwnedIterator(self)
#     502 else:
#     503   raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#     504                      "iteration in eager mode or within tf.function.")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\data\ops\iterator_ops.py:709, in OwnedIterator.__init__(self, dataset, components, element_spec)
#     705   if (components is not None or element_spec is not None):
#     706     raise ValueError(
#     707         "When `dataset` is provided, `element_spec` and `components` must "
#     708         "not be specified.")
# --> 709   self._create_iterator(dataset)
#     711 self._get_next_call_count = 0
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\data\ops\iterator_ops.py:748, in OwnedIterator._create_iterator(self, dataset)
#     745   assert len(fulltype.args[0].args[0].args) == len(
#     746       self._flat_output_types)
#     747   self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748 gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\tensorflow\python\ops\gen_dataset_ops.py:3509, in make_iterator(dataset, iterator, name)
#    3507 if tld.is_eager:
#    3508   try:
# -> 3509     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3510       _ctx, "MakeIterator", name, dataset, iterator)
#    3511     return _result
#    3512   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
import pickle
with open('memory.pkl', 'wb') as f: pickle.dump(memory, f)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model

# Wczytujemy nasz wytrenowany model
new_model = q_network
trained_model = new_model

def test_agent(env, model, n_episodes=5):
    """
    Wykonujemy n_episodes epizodów i zapisujemy trace w postaci:
    (obs, action, reward, next_obs) dla każdego kroku.
    """
    all_episode_rewards = []
    all_traces = []  # aby przechować szczegółowe info do ewentualnej wizualizacji

    for episode_i in range(n_episodes):
        obs_5d = env.reset()
        obs_6d = transform_state(obs_5d)  # Funkcja jak w Twoim kodzie

        episode_reward = 0
        episode_trace = []

        terminated = False
        truncated = False

        while not (terminated or truncated):
            # Wybór akcji - tutaj greedy, bo chcemy pokazać, co robi nauczony agent
            q_values = model.predict(obs_6d[np.newaxis, :], verbose=0)
            action = np.argmax(q_values[0])

            # Krok w środowisku
            next_obs_5d, reward, terminated, truncated = env.step(action)
            next_obs_6d = transform_state(next_obs_5d)

            episode_reward += reward

            # Zapis do trace
            episode_trace.append({
                'obs': obs_5d,
                'action': action,
                'reward': reward,
                'next_obs': next_obs_5d
            })

            # Przechodzimy do następnego stanu
            obs_5d = next_obs_5d
            obs_6d = next_obs_6d

        all_episode_rewards.append(episode_reward)
        all_traces.append(episode_trace)

    # Podsumowanie wyników
    avg_reward = np.mean(all_episode_rewards)
    print(f"Test: średni reward z {n_episodes} epizodów = {avg_reward:.2f}")

    return all_episode_rewards, all_traces

# Uruchamiamy testy
env = WarehouseOrientationEnv(n=64, max_steps=200)
test_rewards, traces = test_agent(env, trained_model, n_episodes=5)
# Out:
# Test: średni reward z 5 epizodów = -0.10

# %%
import matplotlib.pyplot as plt

def visualize_episode(episode_trace):
    """
    Wizualizuje pozycje agenta i celu w kolejnych krokach epizodu.
    Załóżmy, że `episode_trace` to lista słowników, gdzie:
        step['obs'] = [agent_x, agent_y, target_x, target_y, ...]
    """

    # Listy do przechowania kolejnych pozycji agenta i celu
    agent_positions = []
    target_positions = []
    a=print(episode_trace)
    for step in episode_trace:
        # Wyciągamy z obs: [agent_x, agent_y, target_x, target_y, ...]
      agent_x, agent_y   = step['obs'][0], step['obs'][1]
      target_x, target_y = step['obs'][2], step['obs'][3]

      agent_positions.append((agent_x, agent_y))
      target_positions.append((target_x, target_y))

    # Rozbijamy na osobne listy (x, y) — jeśli target się porusza, to zobaczymy jego ścieżkę
    agent_xs  = [pos[0] for pos in agent_positions]
    agent_ys  = [pos[1] for pos in agent_positions]
    target_xs = [pos[0] for pos in target_positions]
    target_ys = [pos[1] for pos in target_positions]

    # Rysujemy ścieżkę agenta
    plt.plot(agent_xs, agent_ys, 'bo-', label='Agent')

    # Rysujemy ścieżkę (lub pozycje) celu
    # Jeśli cel jest statyczny, zobaczysz same nakładające się punkty.
    plt.plot(target_xs, target_ys, 'rx--', label='Cel')

    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Ścieżka agenta i pozycja celu')
    plt.legend()
    plt.grid(True)
    plt.show()

# Załóżmy, że mamy listę epizodów `traces`,
# gdzie np. traces[0] to trace z pierwszego epizodu
episode_trace = traces[5]  # bierzemy pierwszy epizod z listy

# Wywołujemy wizualizację
visualize_episode(episode_trace)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [14], line 44
#      40     plt.show()
#      42 # Załóżmy, że mamy listę epizodów `traces`,
#      43 # gdzie np. traces[0] to trace z pierwszego epizodu
# ---> 44 episode_trace = traces[5]  # bierzemy pierwszy epizod z listy
#      46 # Wywołujemy wizualizację
#      47 visualize_episode(episode_trace)
#
# IndexError: list index out of range
